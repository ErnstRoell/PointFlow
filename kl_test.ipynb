# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
y = stats.norm.rvs(size=1000)

plt.hist(x)
# Out:
# (array([  4.,  28.,  91., 192., 254., 211., 140.,  57.,  17.,   6.]),
#  array([-3.0658771 , -2.42698974, -1.78810238, -1.14921502, -0.51032766,
#          0.1285597 ,  0.76744707,  1.40633443,  2.04522179,  2.68410915,
#          3.32299651]),
#  <BarContainer object of 10 artists>)

# %%
x = stats.norm.rvs(size=1000)
stats.kstest(x, stats.norm.cdf)
# Out:
# KstestResult(statistic=0.026089631881092035, pvalue=0.4958135922305795, statistic_location=0.6773573311487361, statistic_sign=1)

# %%
import numpy as np
from scipy import stats
stats.kstest(x, y)


rng = np.random.default_rng()
stats.kstest(stats.uniform.rvs(size=100, random_state=rng),
             stats.norm.cdf)
# Out:
# KstestResult(statistic=0.5018297574199685, pvalue=7.981346992659216e-24, statistic_location=0.004586537765210896, statistic_sign=-1)

# %%
x = stats.norm.rvs(size=100, random_state=rng)
y = stats.uniform.rvs(size=100, random_state=rng)
stats.kstest(x, y)
# Out:
# KstestResult(statistic=0.52, pvalue=1.070075869779788e-12, statistic_location=0.047271243475453535, statistic_sign=1)

# %%
x.shape
# Out:
# (100,)

# %%
# Out:
# KstestResult(statistic=0.11528822055137844, pvalue=0.47618703970514104, statistic_location=1.164563370562787, statistic_sign=1)

# %%
sample1 = stats.laplace.rvs(size=155, random_state=rng)
sample2 = stats.laplace.rvs(size=95, random_state=rng)
stats.kstest(sample1, sample2)
# Out:
# KstestResult(statistic=0.21833616298811545, pvalue=0.005949043177465442, statistic_location=-0.24267180115581033, statistic_sign=-1)

# %%
plt.hist(sample1)
plt.hist(sample2)
