# %%
import pandas as pd

df = pd.read_csv("table.csv",header=None)

# %%
df
# Out:
#                     0      1      2      3      4       5      6
# 0  PointFlow            8.68  35.19  42.93  70.55   38.96  66.99
# 1  SoftFlow             7.93  28.14  45.27  71.19   38.99  60.02
# 2  ShapeGF              7.02  29.33  24.44  48.30   27.15  43.70
# 3  vae                 11.07  32.81  65.51  73.56  163.24  75.53
# 4  encoder              8.83  31.63  60.64  73.06   61.29  57.52
# 5  encodernormalized    7.69  21.72  42.72  52.95   30.48  36.10

# %%
# Normalized 
df.rank(method='dense', ascending=True).mean(axis=1)
# Out:
# 0    3.571429
# 1    3.428571
# 2    1.571429
# 3    5.857143
# 4    4.428571
# 5    2.142857
# dtype: float64

# %%
df = pd.read_csv("table_origial.csv",header=None)

# %%
df.rank(method='dense', ascending=True).mean(axis=1)
# Out:
# 0    3.714286
# 1    3.285714
# 2    1.714286
# 3    5.571429
# 4    4.285714
# 5    2.428571
# dtype: float64

# %%
df = pd.read_csv("table_gen.csv",header=None)

# %%
df.rank(method='dense', ascending=True).mean(axis=1)
# Out:
# 0    2.285714
# 1    3.000000
# 2    3.857143
# 3    2.000000
# 4    4.571429
# 5    4.571429
# dtype: float64

# %%
df = pd.read_csv("table_gen_normalized.csv",header=None)

# %%
df.rank(method='dense', ascending=True).mean(axis=1)
# Out:
# 0    1.571429
# 1    3.571429
# 2    2.714286
# 3    4.000000
# 4    5.714286
# 5    3.428571
# dtype: float64
